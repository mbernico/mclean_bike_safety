# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from scipy import stats
import datetime

import plotly.plotly as py
from plotly.graph_objs import *

# %%
normal_df = pd.read_csv("normal_il_data_w_geocode.csv")
normal_df = normal_df.drop(['Unnamed: 0'], axis=1)

# %%
normal_df.head()
# Out:
#           id      date         time     fault         motorist_name  \
# 0     14-358  03/26/14  05:18:00 PM   cyclist  Jonathan T. Coughlon
# 1     14-575  06/04/14  03:23:00 PM   unknown       Anna M. Eastman
# 2     14-576  06/04/14  09:40:00 PM   cyclist    Zachery A. Perhoch
# 3  A2014-778  08/14/14  03:40:00 PM   cyclist      Sarah L. Tretter
# 4  A2014-797  08/18/14  05:45:00 PM  motorist    Edward C. Houchens
#
#   motorist_gender insured    veh_make  veh_model veh_year  \
# 0               m       y        ford       edge     2011
# 1               f       y        ford     taurus     2004
# 2               m       y   chevrolet    unknown     2009
# 3               f       y  mitsubishi  outlander     2012
# 4               m       y    cadillac   eldorado     1999
#
#                  ...                location_bike   arrest officer_id  \
# 0                ...                     sidewalk  cyclist       7700
# 1                ...                  parking_lot       no         na
# 2                ...                 intersection  cyclist        954
# 3                ...                     sidewalk  cyclist        871
# 4                ...                    crosswalk       no        700
#
#   m_citation m_section c_citation   c_section hospital  \
# 0        NaN       NaN     237233  11-1002(b)  refused
# 1        NaN       NaN        NaN         NaN  bromenn
# 2        NaN       NaN     241473      11-306  bromenn
# 3        NaN       NaN        NaN         NaN  refused
# 4        NaN       NaN        NaN         NaN       no
#
#                                              summary  \
# 0   cyclist on sidewalk, didn't stop at intersection
# 1                      kids playing in a parking lot
# 2                cyclist ran a red light, hit by car
# 3   cyclist on sidewalk, didn't stop at intersection
# 4  motorist turned into the rear wheel of a cycli...
#
#                            lat_long
# 0  [40.5098029, -89.00439019999999]
# 1   [40.502852, -88.98104599999999]
# 2         [40.5049212, -88.9822318]
# 3  [40.5208051, -88.96081679999999]
# 4         [40.5049212, -88.9822318]
#
# [5 rows x 25 columns]

# %%
normal_df.columns
# Out:
# Index([u'id', u'date', u'time', u'fault', u'motorist_name', u'motorist_gender',
#        u'insured', u'veh_make', u'veh_model', u'veh_year', u'cyclist_name',
#        u'cyclist_gender', u'bike', u'geo_loc', u'location_car',
#        u'location_bike', u'arrest', u'officer_id', u'm_citation', u'm_section',
#        u'c_citation', u'c_section', u'hospital', u'summary', u'lat_long'],
#       dtype='object')

# %%
bloomington_df = pd.read_csv("bloomington_il_engineering_2014plus_w_geocode.csv")

# %%
bloomington_df.head()
# Out:
#          NSTRT              ESTRT REPORT_NO  TYPE  INJA  INJB  INJC  INJK  \
# 0  PROSPECT RD  ELDORADO RD SOUTH  20140017     2     0     0     0     0
# 1      MAIN ST        R T DUNN DR  20140201     2     0     0     0     0
# 2   CLINTON ST          LOCUST ST  14-45717     2     0     0     0     0
# 3   PRAIRIE ST      WASHINGTON ST  14-44522     2     0     0     0     0
# 4   GRIDLEY ST        OAKLAND AVE  14-40522     2     0     0     0     0
#
#    DIST  DIR                ...                LITE    AC_DATE   AC_TIME  \
# 0    60    E                ...                   1   1/4/2014   7:30 PM
# 1     0  NaN                ...                   1  1/30/2014   4:30 PM
# 2     0  NaN                ...                   1  3/30/2014  11:17 AM
# 3     0  NaN                ...                   4  4/12/2014   2:54 AM
# 4     0  NaN                ...                   1   5/4/2014  12:48 PM
#
#    DIRU1  DIRU2  YEAR INTRSECT    ID  \
# 0     NE     SE  2014        N   471
# 1      S      S  2014        Y  1578
# 2      N      E  2014        N   165
# 3      W     NW  2014        Y  1106
# 4      S      W  2014        Y   241
#
#                                         intersection  \
# 0  intersection of PROSPECT RD and ELDORADO RD SOUTH
# 1            intersection of MAIN ST and R T DUNN DR
# 2           intersection of CLINTON ST and LOCUST ST
# 3       intersection of PRAIRIE ST and WASHINGTON ST
# 4         intersection of GRIDLEY ST and OAKLAND AVE
#
#                            lat_long
# 0         [40.4742158, -88.9502491]
# 1         [40.4602899, -88.9930053]
# 2         [40.4847097, -88.9847165]
# 3         [40.4796281, -88.9909237]
# 4  [40.4737946, -88.98983249999999]
#
# [5 rows x 24 columns]

# %%
#how many accidents were in bloomington, and normal

normal_count = normal_df.shape[0]
bloomington_count = bloomington_df.shape[0]

BLOOMINGTON_POP = 78902
NORMAL_POP= 54664

blono_crash_per_capita = bloomington_count / float(BLOOMINGTON_POP)
normal_crash_per_capita = normal_count / float(NORMAL_POP)

print " %0.2f crashes per 10,000 people in bloomington" % ( blono_crash_per_capita * 10000)
print  " %0.2f crashes per 10,000 people in normal" % (normal_crash_per_capita * 10000)


#Going to just use X2 here because lazy, sorry Bayesians.

obs = np.array(([normal_count, NORMAL_POP-normal_count], [bloomington_count, BLOOMINGTON_POP-bloomington_count]))
chi2, p, dof, expected = stats.chi2_contingency(obs)
print 'null hypothesis is that bloomington and normal are equally safe for bikers'
print "p = " +  str(p)
print "fail to reject the null at p < 0.5"
# Out:
#  3.04 crashes per 10,000 people in bloomington
#  2.56 crashes per 10,000 people in normal
# null hypothesis is that bloomington and normal are equally safe for bikers
# p = 0.728471603505
# fail to reject the null at p < 0.5

# %% [markdown]
# # Deeper Statistical Analysis
#
# Problems -
# *  bike accidents are very rare (Future Mike:  Talk to AC.   You've found a zero inflated Poisson problem)
# *  not much commonality between these datasets.
# *  Bloomington's open data sucks
#
#
# Approach
# * take the common variables I do have
# * engineer features
# * descriptive stats on when accidents happen maybe?
# * could try unsupervised ML
# * ???

# %%
#combine common fields across datasets.
normal_clean = pd.DataFrame()
normal_clean['date'] = normal_df.date
normal_clean['time'] = normal_df.time
normal_clean['geo_loc'] = normal_df.geo_loc
normal_clean['lat_long'] = normal_df.lat_long
normal_clean['id'] = normal_df.id

bloomington_clean = pd.DataFrame()
bloomington_clean['date'] = bloomington_df.AC_DATE
bloomington_clean['time'] = bloomington_df.AC_TIME
bloomington_clean['geo_loc'] = bloomington_df.intersection
bloomington_clean['lat_long'] = bloomington_df.lat_long
bloomington_clean['id'] = bloomington_df.REPORT_NO

complete_df = bloomington_clean.append(normal_clean, ignore_index=True)

# %%
complete_df.head()
# Out:
#         date      time                                            geo_loc  \
# 0   1/4/2014   7:30 PM  intersection of PROSPECT RD and ELDORADO RD SOUTH
# 1  1/30/2014   4:30 PM            intersection of MAIN ST and R T DUNN DR
# 2  3/30/2014  11:17 AM           intersection of CLINTON ST and LOCUST ST
# 3  4/12/2014   2:54 AM       intersection of PRAIRIE ST and WASHINGTON ST
# 4   5/4/2014  12:48 PM         intersection of GRIDLEY ST and OAKLAND AVE
#
#                            lat_long        id
# 0         [40.4742158, -88.9502491]  20140017
# 1         [40.4602899, -88.9930053]  20140201
# 2         [40.4847097, -88.9847165]  14-45717
# 3         [40.4796281, -88.9909237]  14-44522
# 4  [40.4737946, -88.98983249999999]  14-40522

# %%
#break out month, day, year

def get_month_day_year(date):
    month, day, year = date.split("/")

    return int(month), int(day), int(year)

complete_df['month'], complete_df['day'], complete_df['year'] = zip(*complete_df.date.map(get_month_day_year))

# %%
#time as an hour bin (could also do seconds of day or something for continuous, this is more human understandable)

def bin_hours(time):
    hour = int(time.split(':')[0])
    am_pm = time.split(' ')[1].lower()
    if am_pm == 'pm':
        hour +=12
    return hour

complete_df['hour_bin'] = complete_df.time.map(bin_hours)

# %%
#clean up lat and long

def clean_lat_long(x):
    x = x.strip('[]')
    latitude, longitude = x.split(',')
    return float(latitude), float(longitude)


complete_df['latitude'], complete_df['longitude'] = zip(*complete_df.lat_long.map(clean_lat_long))

# %%
#day of week feature

def day_of_week(date):
    month, day, year = (int(x) for x in date.split('/'))
    if year < 99:
        year = 2000 + year   #do you want y3k, because this is how you get y3k
    dt = datetime.date(year, month, day)
    return dt.strftime("%A")

complete_df['day_of_week'] = complete_df.date.map(day_of_week)

# %% [markdown]
# ###TODO
#
# *  MDS
# *  K-Means

# %%
#month histogram

data = Data([
    Histogram(
        x = complete_df.month.values,
        histnorm='count',
        autobinx=False,
        xbins=XBins(
        start=0,
        end=12,
        size=1
    ),
)])

layout = Layout(
    title='What Months Do Crashes Occur At?',
    
     xaxis=XAxis(
        title='Month'
    ),
    yaxis=YAxis(
        title='Count'
    ),
)

fig=Figure(data=data, layout=layout)
plot_url = py.plot(fig, filename='month_hist')

# %%
#hour histogram

data = Data([
    Histogram(
        x = complete_df.hour_bin.values,
        histnorm='count',
        autobinx=False,
        xbins=XBins(
        start=0,
        end=23,
        size=1
    ),
)])

layout = Layout(
    title='What Times Do Crashes Occur At?',
    
     xaxis=XAxis(
        title='Hour'
    ),
    yaxis=YAxis(
        title='Count'
    ),
)

fig=Figure(data=data, layout=layout)
plot_url = py.plot(fig, filename='hour_hist')

# %%
#day of week histogram

data = Data([
    Histogram(
        x = complete_df.day_of_week.values,
        histnorm='count',
        autobinx=False,
        xbins=XBins(
        start=0,
        end=7,
        size=1
    ),
)])

layout = Layout(
    title='What Day of the Week Do Crashes Occur At?',
    
     xaxis=XAxis(
        title='Day'
    ),
    yaxis=YAxis(
        title='Count'
    ),
)

fig=Figure(data=data, layout=layout)
plot_url = py.plot(fig, filename='day_hist')
